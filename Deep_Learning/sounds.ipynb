# %%
import torchaudio
import matplotlib.pyplot as plt

from pydub import AudioSegment

audio = AudioSegment.from_mp3("sound.mp3")
audio.export("sound.wav", format="wav")


# # Load audio file
# waveform, sample_rate = torchaudio.load("sound.wav")

# print("Sample rate:", sample_rate)
# print("Shape:", waveform.shape)   # (channels, samples)
# Out:
# c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 import matplotlib.pyplot as plt
#       4 from pydub import AudioSegment
# ----> 6 audio = AudioSegment.from_mp3("sound.mp3")
#       7 audio.export("sound.wav", format="wav")
#      10 # # Load audio file
#      11 # waveform, sample_rate = torchaudio.load("sound.wav")
#      12
#      13 # print("Sample rate:", sample_rate)
#      14 # print("Shape:", waveform.shape)   # (channels, samples)
#
# File c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\audio_segment.py:796, in AudioSegment.from_mp3(cls, file, parameters)
#     794 @classmethod
#     795 def from_mp3(cls, file, parameters=None):
# --> 796     return cls.from_file(file, 'mp3', parameters=parameters)
#
# File c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\audio_segment.py:728, in AudioSegment.from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     726     info = None
#     727 else:
# --> 728     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#     729 if info:
#     730     audio_streams = [x for x in info['streams']
#     731                      if x['codec_type'] == 'audio']
#
# File c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\site-packages\pydub\utils.py:274, in mediainfo_json(filepath, read_ahead_limit)
#     271         file.close()
#     273 command = [prober, '-of', 'json'] + command_args
# --> 274 res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#     275 output, stderr = res.communicate(input=stdin_data)
#     276 output = output.decode("utf-8", 'ignore')
#
# File c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\subprocess.py:1028, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1024         if self.text_mode:
#    1025             self.stderr = io.TextIOWrapper(self.stderr,
#    1026                     encoding=encoding, errors=errors)
# -> 1028     self._execute_child(args, executable, preexec_fn, close_fds,
#    1029                         pass_fds, cwd, env,
#    1030                         startupinfo, creationflags, shell,
#    1031                         p2cread, p2cwrite,
#    1032                         c2pread, c2pwrite,
#    1033                         errread, errwrite,
#    1034                         restore_signals,
#    1035                         gid, gids, uid, umask,
#    1036                         start_new_session, process_group)
#    1037 except:
#    1038     # Cleanup if the child failed starting.
#    1039     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\smi09\AppData\Local\anaconda3\envs\deeplearning\Lib\subprocess.py:1540, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1538 # Start the process
#    1539 try:
# -> 1540     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1541                              # no special security
#    1542                              None, None,
#    1543                              int(not close_fds),
#    1544                              creationflags,
#    1545                              env,
#    1546                              cwd,
#    1547                              startupinfo)
#    1548 finally:
#    1549     # Child is launched. Close the parent's copy of those pipe
#    1550     # handles that only the child should have open.  You need
#    (...)   1553     # pipe will not close when the child process exits and the
#    1554     # ReadFile will hang.
#    1555     self._close_pipe_fds(p2cread, p2cwrite,
#    1556                          c2pread, c2pwrite,
#    1557                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
